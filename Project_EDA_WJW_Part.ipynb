# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %%
Attdata = pd.read_csv('Attrition.csv')
Attdata.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
print("Data type : ", type(Attdata))
print("Data dims : ", Attdata.shape)
# Out:
# Data type :  <class 'pandas.core.frame.DataFrame'>
# Data dims :  (1470, 35)

# %%
print(Attdata.dtypes)
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
Attdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
Attdata['Attrition'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
Attdata.loc[Attdata['Attrition'] == 'Yes','Attrition'] = 1
Attdata.loc[Attdata['Attrition'] == 'No','Attrition'] = 0
variable = pd.DataFrame(Attdata['Attrition'])
print("Data type : ", type(variable))
print("Data dims : ", variable.size)
variable.head()
# Out:
# Data type :  <class 'pandas.core.frame.DataFrame'>
# Data dims :  1470
#   Attrition
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %%
Attdata['Attrition'] = pd.to_numeric(Attdata['Attrition'])

# %%
print(Attdata["Attrition"].value_counts())
sb.catplot(y = "Attrition", data = Attdata, kind = "count")
# Out:
# 0    1233
# 1     237
# Name: Attrition, dtype: int64

# %%
df = pd.DataFrame(Attdata[['Attrition', 'DailyRate', 'HourlyRate', 'MonthlyRate', 'JobInvolvement', 'PerformanceRating',
                          'DistanceFromHome', 'EnvironmentSatisfaction', 'JobSatisfaction', 'MonthlyIncome', 'PercentSalaryHike']])

# %%
df.describe().round(2)
# Out:
#        Attrition  DailyRate  HourlyRate  MonthlyRate  JobInvolvement  \
# count    1470.00    1470.00     1470.00      1470.00         1470.00
# mean        0.16     802.49       65.89     14313.10            2.73
# std         0.37     403.51       20.33      7117.79            0.71
# min         0.00     102.00       30.00      2094.00            1.00
# 25%         0.00     465.00       48.00      8047.00            2.00
# 50%         0.00     802.00       66.00     14235.50            3.00
# 75%         0.00    1157.00       83.75     20461.50            3.00
# max         1.00    1499.00      100.00     26999.00            4.00
#
#        PerformanceRating  DistanceFromHome  EnvironmentSatisfaction  \
# count            1470.00           1470.00                  1470.00
# mean                3.15              9.19                     2.72
# std                 0.36              8.11                     1.09
# min                 3.00              1.00                     1.00
# ...

# %%
f, axes = plt.subplots(11, 3, figsize=(30, 40))

count = 0
for var in df:
    sb.boxplot(data = df[var], orient = "h", ax = axes[count,0])
    sb.histplot(data = df[var], ax = axes[count,1])
    sb.violinplot(data = df[var], orient = "h", ax = axes[count,2])
    count += 1

# %%
print('Numerical variables vs Attrition')
f,ax=plt.subplots(8,1,figsize=(10, 25)) 
for i, name in enumerate(df):
    sns.boxplot(x=name,y='Attrition', data=df,orient='h',ax=ax[i])
# Out:
# Numerical variables vs Attrition
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-065151f0da92> in <module>
#       2 f,ax=plt.subplots(8,1,figsize=(10, 25))
#       3 for i, name in enumerate(df):
# ----> 4     sns.boxplot(x=name,y='Attrition', data=df,orient='h',ax=ax[i])
#
# NameError: name 'sns' is not defined

# %%
# Correlation Matrix
print(df.corr())

# Heatmap of the Correlation Matrix
f = plt.figure(figsize=(20, 20))
sb.heatmap(df.corr(), vmin = -1, vmax = 1, linewidths = 1,
           annot = True, fmt = ".2f", annot_kws = {"size": 18}, cmap = "RdBu")
# 如果全是 numerical 的，可以用 corr
# spearman , 如果 混杂 Person
# Out:
#                          Attrition  DailyRate  HourlyRate  MonthlyRate  \
# Attrition                 1.000000  -0.056652   -0.006846     0.015170
# DailyRate                -0.056652   1.000000    0.023381    -0.032182
# HourlyRate               -0.006846   0.023381    1.000000    -0.015297
# MonthlyRate               0.015170  -0.032182   -0.015297     1.000000
# JobInvolvement           -0.130016   0.046135    0.042861    -0.016322
# PerformanceRating         0.002889   0.000473   -0.002172    -0.009811
# DistanceFromHome          0.077924  -0.004985    0.031131     0.027473
# EnvironmentSatisfaction  -0.103369   0.018355   -0.049857     0.037600
# JobSatisfaction          -0.103481   0.030571   -0.071335     0.000644
# MonthlyIncome            -0.159840   0.007707   -0.015794     0.034814
# PercentSalaryHike        -0.013478   0.022704   -0.009062    -0.006429
#
#                          JobInvolvement  PerformanceRating  DistanceFromHome  \
# ...

# %%
# Draw pairs of variables against one another
sb.pairplot(data = df)

# %%
y = pd.DataFrame(Attdata['Attrition'])   # Response
X = pd.DataFrame(Attdata[[ 'DailyRate', 'HourlyRate', 'MonthlyRate', 'JobInvolvement', 'PerformanceRating',
                          'DistanceFromHome', 'EnvironmentSatisfaction', 'JobSatisfaction', 'MonthlyIncome', 'PercentSalaryHike']])

# %%
# Relationship between Response and the Predictors
trainDF = pd.concat([y, X], axis = 1).reindex(y.index)

f, axes = plt.subplots(10, 1, figsize=(20, 36))

count = 0
for var in X:
    sb.swarmplot(x = var, y = "Attrition", data = trainDF, orient = "h", ax = axes[count])
    count += 1
# Out:
# /Users/wangjiwei/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 27.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/wangjiwei/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 95.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/wangjiwei/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 78.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/wangjiwei/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 97.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
from sklearn.utils import resample
# Separate majority and minority classes
df_majority = Attdata[Attdata.Attrition==0]
df_minority = Attdata[Attdata.Attrition==1]
 
# Downsample majority class
df_majority_downsampled = resample(df_majority, 
                                 replace=False,    # sample without replacement
                                 n_samples=237,     # to match minority class
                                 random_state=123) # reproducible results
 
# Combine minority class with downsampled majority class
df_downsampled = pd.concat([df_majority_downsampled, df_minority])
 
# Display new class counts
df_downsampled.Attrition.value_counts()
# Out:
# 0    237
# 1    237
# Name: Attrition, dtype: int64

# %%
y = df_downsampled.Attrition
X = df_downsampled.drop('Attrition', axis=1)
